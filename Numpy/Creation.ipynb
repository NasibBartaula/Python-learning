# %%
import numpy as np
arr=np.array([2,3,4,5,6,8])
print(arr)
print(type(arr))
# Out:
# [2 3 4 5 6 8]
# <class 'numpy.ndarray'>

# %%
place=["kathmandu","hetauda","pokhara","dharan"]
plac=np.array(place)
print(plac)
# Out:
# ['kathmandu' 'hetauda' 'pokhara' 'dharan']

# %%
print(plac.shape)
print(plac.size)
print(len(plac))
print(plac.ndim)
print(type(plac))
print(plac.dtype)
# Out:
# (4,)
# 4
# 4
# 1
# <class 'numpy.ndarray'>
# <U9
