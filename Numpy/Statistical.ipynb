# %%
import numpy as np
import statistics as stacs
a=np.array([100,200,300,400,300,150,100])
print(np.mean(a))
print(np.median(a))
print(stacs.mode(a))
print(np.std(a))
print(np.var(a))
# Out:
# 221.42857142857142
# 200.0
# 100
# 106.42617446965242
# 11326.530612244898

# %%
smokers=np.array([22,12,14,15,16])
deadth=np.array([100,123,345,666,887])
print(np.corrcoef([smokers,deadth]))
# Out:
# [[ 1.         -0.15864075]
#  [-0.15864075  1.        ]]
