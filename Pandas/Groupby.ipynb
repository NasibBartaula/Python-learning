# %%
import pandas as pd
a=pd.read_csv("detail.csv.txt")
print(a)
# Out:
#     StudentID    Name   Age  Gender Course  Math  Science  English  Attendance
# 0           1     NaN  20.0    Male    BCA    78       85       74          90
# 1           2    Sita   NaN  Female    BCA    88       92       81          95
# 2           3    Hari  21.0     NaN    BCA    67       73       70          80
# 3           4    Gita  20.0  Female    BCA    91       89       94          98
# 4           5   Shyam  22.0    Male    BCA    56       60       58          75
# 5           6    Hari  21.0    Male    BCA    67       73       70          80
# 6           7    Hari  21.0    Male    BCA    67       73       70          80
# 7           8   Kiran  22.0    Male    BCA    61       70       64          78
# 8           9   Anita  19.0  Female    BCA    84       79       88          92
# 9          10    Hari  21.0    Male    BCA    67       73       70          80
# 10         11   Kiran  22.0    Male    BCA    61       70       64          78
# ...

# %%
gp=a.groupby(["Course","Gender"]).agg({"StudentID":"count"})
print(gp)
gp=a.groupby(["Age"]).agg({"Math":"mean"})
# Out:
#                StudentID
# Course Gender
# BCA    Female          5
#        Male            8
