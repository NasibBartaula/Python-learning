# %%
import pandas as pd
a=pd.read_csv("detail.csv.txt")
print(a)
# Out:
#     StudentID    Name   Age  Gender Course  Math  Science  English  Attendance
# 0           1     NaN  20.0    Male    BCA    78       85       74          90
# 1           2    Sita   NaN  Female    BCA    88       92       81          95
# 2           3    Hari  21.0     NaN    BCA    67       73       70          80
# 3           4    Gita  20.0  Female    BCA    91       89       94          98
# 4           5   Shyam  22.0    Male    BCA    56       60       58          75
# 5           6    Hari  21.0    Male    BCA    67       73       70          80
# 6           7    Hari  21.0    Male    BCA    67       73       70          80
# 7           8   Kiran  22.0    Male    BCA    61       70       64          78
# 8           9   Anita  19.0  Female    BCA    84       79       88          92
# 9          10    Hari  21.0    Male    BCA    67       73       70          80
# 10         11   Kiran  22.0    Male    BCA    61       70       64          78
# ...

# %%
print(a.isnull().sum())
# Out:
# StudentID     0
# Name          1
# Age           1
# Gender        1
# Course        0
# Math          0
# Science       0
# English       0
# Attendance    0
# dtype: int64

# %%
print(a.dropna())
# Out:
#     StudentID    Name   Age  Gender Course  Math  Science  English  Attendance
# 3           4    Gita  20.0  Female    BCA    91       89       94          98
# 4           5   Shyam  22.0    Male    BCA    56       60       58          75
# 5           6    Hari  21.0    Male    BCA    67       73       70          80
# 6           7    Hari  21.0    Male    BCA    67       73       70          80
# 7           8   Kiran  22.0    Male    BCA    61       70       64          78
# 8           9   Anita  19.0  Female    BCA    84       79       88          92
# 9          10    Hari  21.0    Male    BCA    67       73       70          80
# 10         11   Kiran  22.0    Male    BCA    61       70       64          78
# 11         12  Prisha  20.0  Female    BCA    95       96       93          99
# 12         13   Kiran  22.0    Male    BCA    61       70       64          78
# 13         14   Nisha  19.0  Female    BCA    89       87       90          96

# %%
import numpy as np
a["Age"] = pd.to_numeric(a["Age"])
print(a["Age"].mean())
print(a.replace(np.nan,100))
# Out:
#     StudentID    Name   Age   Gender Course  Math  Science  English  \
# 0           1    User  20.0     Male    BCA    78       85       74
# 1           2    Sita  30.0   Female    BCA    88       92       81
# 2           3    Hari  21.0  Unknown    BCA    67       73       70
# 3           4    Gita  20.0   Female    BCA    91       89       94
# 4           5   Shyam  22.0     Male    BCA    56       60       58
# 5           6    Hari  21.0     Male    BCA    67       73       70
# 6           7    Hari  21.0     Male    BCA    67       73       70
# 7           8   Kiran  22.0     Male    BCA    61       70       64
# 8           9   Anita  19.0   Female    BCA    84       79       88
# 9          10    Hari  21.0     Male    BCA    67       73       70
# 10         11   Kiran  22.0     Male    BCA    61       70       64
# 11         12  Prisha  20.0   Female    BCA    95       96       93
# 12         13   Kiran  22.0     Male    BCA    61       70       64
# ...

# %%
a["Name"]=a["Name"].bfill()
a["Age"]=a["Age"].replace(np.nan,"21.42")
print(a)
# Out:
#     StudentID    Name   Age   Gender Course  Math  Science  English  \
# 0           1    User  20.0     Male    BCA    78       85       74
# 1           2    Sita  30.0   Female    BCA    88       92       81
# 2           3    Hari  21.0  Unknown    BCA    67       73       70
# 3           4    Gita  20.0   Female    BCA    91       89       94
# 4           5   Shyam  22.0     Male    BCA    56       60       58
# 5           6    Hari  21.0     Male    BCA    67       73       70
# 6           7    Hari  21.0     Male    BCA    67       73       70
# 7           8   Kiran  22.0     Male    BCA    61       70       64
# 8           9   Anita  19.0   Female    BCA    84       79       88
# 9          10    Hari  21.0     Male    BCA    67       73       70
# 10         11   Kiran  22.0     Male    BCA    61       70       64
# 11         12  Prisha  20.0   Female    BCA    95       96       93
# 12         13   Kiran  22.0     Male    BCA    61       70       64
# ...
