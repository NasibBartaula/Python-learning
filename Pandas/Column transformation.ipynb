# %%
import pandas as pd
a=pd.read_csv("detail.csv.txt")
print(a)
a.loc[a["Math"]>=70,"Brain"]="Talent"
a.loc[a["Math"]<70,"Brain"]="Not_talent"
print(a.head(10))
# Out:
#     StudentID    Name   Age  Gender Course  Math  Science  English  Attendance
# 0           1     NaN  20.0    Male    BCA    78       85       74          90
# 1           2    Sita   NaN  Female    BCA    88       92       81          95
# 2           3    Hari  21.0     NaN    BCA    67       73       70          80
# 3           4    Gita  20.0  Female    BCA    91       89       94          98
# 4           5   Shyam  22.0    Male    BCA    56       60       58          75
# 5           6    Hari  21.0    Male    BCA    67       73       70          80
# 6           7    Hari  21.0    Male    BCA    67       73       70          80
# 7           8   Kiran  22.0    Male    BCA    61       70       64          78
# 8           9   Anita  19.0  Female    BCA    84       79       88          92
# 9          10    Hari  21.0    Male    BCA    67       73       70          80
# 10         11   Kiran  22.0    Male    BCA    61       70       64          78
# ...

# %%
b=pd.read_excel("Manahari.xlsx")
print(b)
b["calculate"]=b["Age"]*b["Salary"]
print(b)
# Out:
#       Name  Age  Salary      Work     Place
# 0    Yujan   23    2000    Doctor  Manahari
# 1    Nasib   21    7000  Engineer  Manahari
# 2    Suhim   34   85000     Pilot  Manahari
# 3  Binayak   23   55440   Teacher  Manahari
# 4  Bikalpa   43   85200    Rapper  Manahari
# 5    Sahil   54   54100    Singer  Manahari
# 6   Dipson   44   53600   Bouncer  Manahari
# 7  Nischal   23   84100    Doctor  Manahari
# 8   Saurav   34   45000   Teacher  Manahari
# 9    James   32   32000   Dentist  Manahari
#       Name  Age  Salary      Work     Place  calculate
# 0    Yujan   23    2000    Doctor  Manahari      46000
# 1    Nasib   21    7000  Engineer  Manahari     147000
# 2    Suhim   34   85000     Pilot  Manahari    2890000
# 3  Binayak   23   55440   Teacher  Manahari    1275120
# 4  Bikalpa   43   85200    Rapper  Manahari    3663600
# 5    Sahil   54   54100    Singer  Manahari    2921400
# 6   Dipson   44   53600   Bouncer  Manahari    2358400
# ...
