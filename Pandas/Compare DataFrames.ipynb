# %%
import pandas as pd
dict={"fruit":["apple","banana","mango"],
     "price":[50,60,70], 
     "quality":[10,5,15]
     }
this=pd.DataFrame(dict)
that=this.copy()
that.loc[0,"price"]=100
that.loc[1,"price"]=120
that.loc[2,"price"]=80
print(this)
print(that)
print(this.compare(that))
print(this.compare(that,keep_shape=True))
# Out:
#     fruit  price  quality
# 0   apple     50       10
# 1  banana     60        5
# 2   mango     70       15
#     fruit  price  quality
# 0   apple    100       10
# 1  banana    120        5
# 2   mango     80       15
#   price
#    self other
# 0    50   100
# 1    60   120
# 2    70    80
#   fruit       price       quality
#    self other  self other    self other
# 0   NaN   NaN    50   100     NaN   NaN
# 1   NaN   NaN    60   120     NaN   NaN
# 2   NaN   NaN    70    80     NaN   NaN
