# %%
import pandas as pd
a=pd.read_csv("detail.csv.txt")
print(a)
print(a.duplicated().sum())
print(a.drop_duplicates("StudentID"))
# Out:
#     StudentID    Name  Age  Gender Course  Math  Science  English  Attendance
# 0           1     Ram   20    Male    BCA    78       85       74          90
# 1           2    Sita   19  Female    BCA    88       92       81          95
# 2           3    Hari   21    Male    BCA    67       73       70          80
# 3           4    Gita   20  Female    BCA    91       89       94          98
# 4           5   Shyam   22    Male    BCA    56       60       58          75
# 5           3    Hari   21    Male    BCA    67       73       70          80
# 6           3    Hari   21    Male    BCA    67       73       70          80
# 7           6   Kiran   22    Male    BCA    61       70       64          78
# 8           7   Anita   19  Female    BCA    84       79       88          92
# 9           3    Hari   21    Male    BCA    67       73       70          80
# 10          6   Kiran   22    Male    BCA    61       70       64          78
# ...
