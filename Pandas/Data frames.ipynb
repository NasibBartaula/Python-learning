# %%
import pandas as pd
data={
    "name":["Nasib","Suhim","Yujan","Bikalpa"],
    "age":[20,21,19,20],
    "salary":[15000,30000,25000,15000]
}
df=pd.DataFrame(data)
print(df.head(12)) 
#print(df.tail(6))  #default is head 5 and tail 5.
print(df.info())
# Out:
#       name  age  salary
# 0    Nasib   20   15000
# 1    Suhim   21   30000
# 2    Yujan   19   25000
# 3  Bikalpa   20   15000
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      str
#  1   age     4 non-null      int64
#  2   salary  4 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes
# None

# %%
data=pd.read_excel("Manahari.xlsx")
print(data)
#print(data.head(3)) 
#print(data.tail(3))  #default is head 5 and tail 5.
print(data. info())
print(data.describe())
print(data.isnull().sum())
# Out:
#       Name  Age  Salary      Work     Place
# 0    Yujan   23    2000    Doctor  Manahari
# 1    Nasib   21    7000  Engineer  Manahari
# 2    Suhim   34   85000     Pilot  Manahari
# 3  Binayak   23   55440   Teacher  Manahari
# 4  Bikalpa   43   85200    Rapper  Manahari
# 5    Sahil   54   54100    Singer  Manahari
# 6   Dipson   44   53600   Bouncer  Manahari
# 7  Nischal   23   84100    Doctor  Manahari
# 8   Saurav   34   45000   Teacher  Manahari
# 9    James   32   32000   Dentist  Manahari
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     str
#  1   Age     10 non-null     int64
#  2   Salary  10 non-null     int64
#  3   Work    10 non-null     str
#  4   Place   10 non-null     str
# dtypes: int64(2), str(3)
# memory usage: 532.0 bytes
# None
#             Age        Salary
# count  10.00000     10.000000
# ...
