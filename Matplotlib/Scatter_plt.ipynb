# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
x=np.random.randint(1,10,50)
y=np.random.randint(10,100,50)
color=np.random.randint(10,100,50)
size=np.random.randint(10,100,50)
plt.scatter(x,y,marker="*",c=color,cmap="hot",s=size)
plt.colorbar
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_excel("C:/Users/HP TH/Downloads/profit.xlsx")
df=pd.DataFrame(data)
print(df)
plt.scatter(df["Sales"],df["Expenses"])
# Out:
#          Day  Sales  Expenses  Profit (Sales - Expenses)
# 0     Monday    200       150                         50
# 1    Tuesday    250       200                         50
# 2  Wednesday    180       120                         60
# 3   Thursday    300       220                         80
# 4     Friday    280       210                         70
# 5   Saturday    350       300                         50
# 6     Sunday    400       320                         80
