# %%
import matplotlib.pyplot as plt
y=[98,89,79,67,75]
x=["class1","class2","class3","class4","class5"]
color=["red","green","yellow","blue","violet"]
plt.bar(x,y,color=color,edgecolor="black")
plt.ylabel("Percentage",fontsize=20)
plt.xlabel("Grade",fontsize=20)
plt.show()

# %%
import pandas as pd
x=pd.read_excel("C:/Users/HP TH/Downloads/profit.xlsx")
print(x)
plt.bar(x["Day"],y["Sales"],edgecolor="black")
plt.xlabel("Days",fontsize=20)
plt.ylabel("Sales",fontsize=20)
plt.show()
gp=x.groupby(["Day"]).agg({"Sales":"sum"})
print(gp)
plt.bar(gp.index,gp["Sales"])
# Out:
#          Day  Sales  Expenses  Profit (Sales - Expenses)
# 0     Monday    200       150                        NaN
# 1    Tuesday    250       200                        NaN
# 2  Wednesday    180       120                        NaN
# 3   Thursday    300       220                        NaN
# 4     Friday    280       210                        NaN
# 5   Saturday    350       300                        NaN
# 6     Sunday    400       320                        NaN
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[97], line 8
#       6 plt.ylabel("Sales",fontsize=20)
#       7 plt.show()
# ----> 8 gp=x.groupby(["Day"]).agg({"Sales":"sum"}).reindex(order)
#       9 print(gp)
#      10 plt.bar(gp.index,gp["Sales"])
#
# NameError: name 'order' is not defined
