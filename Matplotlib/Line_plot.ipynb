# %%
import matplotlib.pyplot as plt
x=["day1","day2","day3","day4","day5"]
y=[400,300,130,50,600]
y1=[210,120,235,400,30]
plt.plot(x,y,marker="o",ls=":",color="blue")
plt.plot(x,y1,marker="o",color="green",alpha=1)

# %%
import pandas as pd
data=pd.read_excel("C:/Users/HP TH/Downloads/profit.xlsx")
df=pd.DataFrame(data)
print(df)
plt.plot(df["Day"],df["Expenses"],marker="o",ls=":",color="red",alpha=1)
plt.plot(df["Day"],df["Sales"],marker="o",color="green",alpha=1)
# Out:
#          Day  Sales  Expenses  Profit (Sales - Expenses)
# 0     Monday    200       150                         50
# 1    Tuesday    250       200                         50
# 2  Wednesday    180       120                         60
# 3   Thursday    300       220                         80
# 4     Friday    280       210                         70
# 5   Saturday    350       300                         50
# 6     Sunday    400       320                         80
