# %%
import matplotlib.pyplot as plt
a=[20,30,20,40,50,40,60,70,60,50,44,33,25,77,45,65,4,5,3]
plt.violinplot(a,showmedians=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
x=pd.read_excel("C:/Users/HP TH/default/Python_learning/Pandas/Manahari.xlsx")
y=pd.DataFrame(x)
plt.violinplot(y["Salary"],showmedians=True)
plt.show()
