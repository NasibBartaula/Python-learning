# %%
import matplotlib.pyplot as plt
days=[1,2,3,4,5,6,7]
nop1=[20,10,20,30,40,7,1]
nop2=[20,29,39,40,54,9,3]
nop3=[60,50,40,30,38,34,43]
plt.stackplot(days,nop1,nop2,nop3,colors=["green","red","blue"],labels=["week1","week2","week3"])
plt.legend()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 4
#       2 x=pd.read_excel("C:/Users/HP TH/default/Python_learning/Pandas/Manahari.xlsx")
#       3 y=pd.DataFrame(x)
# ----> 4 df=y.groupby(["Name"])["Salary","Age"].mean()
#       5 plt.stackplot(y["Name"].unique(),df["Salary"],df["Age"])
#       6 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\generic.py:2934, in DataFrameGroupBy.__getitem__(self, key)
#    2929 def __getitem__(self, key) -> DataFrameGroupBy | SeriesGroupBy:
#    2930     # per GH 23566
#    2931     if isinstance(key, tuple) and len(key) > 1:
#    2932         # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933         # valid syntax, so don't raise
# -> 2934         raise ValueError(
# ...
