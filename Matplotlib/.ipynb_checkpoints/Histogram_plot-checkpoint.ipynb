# %%
import matplotlib.pyplot as plt
x=[56,45,56,67,87,56,76,56,85,99,67,65,1,3,2,22,24,25,26]
plt.hist(x,bins=20,edgecolor="black",color="green")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
x=pd.read_excel("C:/Users/HP TH/default/Python_learning/Pandas/Manahari.xlsx")
y=pd.DataFrame(x)
plt.hist(y["Age"],bins=7)
plt.show()
