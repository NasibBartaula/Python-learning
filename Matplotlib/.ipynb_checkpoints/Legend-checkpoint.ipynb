# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[23,45,34,23,65]
y1=[32,67,43,65,76]
plt.figure(figsize=[5,3])
plt.plot(x,y,label="Male")
plt.plot(x,y1,label="Female")
plt.legend(["a1","a2"],bbox_to_anchor=[0.8,1.3])
plt.show()
