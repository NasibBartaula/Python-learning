# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[23,34,54,26,54]
plt.subplot(1,2,1)
plt.title("Age")
plt.bar(x,y)

x=[5,6,7,8,9]
y=[76,56,87,98,65]
plt.subplot(1,2,2)
plt.title("Weight")
plt.plot(x,y)
plt.show()
