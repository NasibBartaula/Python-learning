# %%
import matplotlib.pyplot as plt
l=[12,23,34,52,34,45,75,86,45,34,55,65,74,35,76,89,140]
plt.boxplot(l)
plt.show()

# %%
import matplotlib.pyplot as plt
l=[12,23,34,52,34,45,75,86,45,34,55,65,74,35,76,89,140]
m=[100,200,455,233,655,344,122,877]
n=[l,m]
plt.boxplot(n)
plt.boxplot(l)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
x=pd.read_excel("C:/Users/HP TH/default/Python_learning/Pandas/Manahari.xlsx")
y=pd.DataFrame(x)
print(y)
plt.boxplot(y["Salary"])
# Out:
#       Name  Age  Salary      Work     Place
# 0    Yujan   23    2000    Doctor  Manahari
# 1    Nasib   21    7000  Engineer  Manahari
# 2    Suhim   34   85000     Pilot  Manahari
# 3  Binayak   23   55440   Teacher  Manahari
# 4  Bikalpa   43   85200    Rapper  Manahari
# 5    Sahil   54   54100    Singer  Manahari
# 6   Dipson   44   53600   Bouncer  Manahari
# 7  Nischal   23   84100    Doctor  Manahari
# 8   Saurav   34   45000   Teacher  Manahari
# 9    James   32   32000   Dentist  Manahari
# {'whiskers': [<matplotlib.lines.Line2D at 0x26474a8c410>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26474a8f9d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26474a8ca50>],
#  'medians': [<matplotlib.lines.Line2D at 0x26474a8fc50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26474a8e5d0>],
#  'means': []}
